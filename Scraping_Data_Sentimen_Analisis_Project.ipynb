# %% [markdown]
# #Scraping Data

# %% [markdown]
# 1. Library Installation

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.7)

# %% [markdown]
# 2. Importing Library

# %%
from google_play_scraper import Sort, reviews_all
import csv
import pandas as pd

# %% [markdown]
# 3. Scrapping Details

# %%
#Mengambil ulasan dari site
scrapreview = reviews_all(
    'id.bni.wondr',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=150000
)

scrapreview_limited = scrapreview[:150000]

# %% [markdown]
# 4. Output Details

# %%
dataView = pd.DataFrame(scrapreview_limited)
dataView.head()
# Out:
#                                reviewId         userName  \
# 0  8071c4a9-6c75-4bc4-8f0a-3b72fd856210  Pengguna Google
# 1  2f525491-c23a-4ccf-9aa9-124145ed658e  Pengguna Google
# 2  12ebf418-211f-45c1-9675-081315eee3f9  Pengguna Google
# 3  5e2a6af2-4f7b-4a44-a0bf-ba6d7def80b5  Pengguna Google
# 4  de753f03-5965-412e-a322-b6f38f12730c  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Sering banget eror, sering banget perbaikan da...      1            229
# 1  Kenapa data yg kita masukkan gak ter save. Set...      1              4
# 2  Terimakasih sudah ada menu total pengeluaran/p...      4              7
# 3  Baru download karena disarankan cs bank, pada ...      1            134
# 4  Nah suruh migrasi tapi belum siap, tarik tunai...      1             54
#
#   reviewCreatedVersion                  at  \
# 0                1.2.0 2024-12-21 21:29:07
# 1                1.2.0 2025-01-02 05:20:24
# 2                1.2.0 2024-12-26 06:25:24
# 3                1.2.0 2024-12-17 04:29:44
# 4                1.2.0 2024-12-21 01:06:50
#
#                                         replyContent           repliedAt  \
# 0  Hai Kak Kharisma Mega, maaf atas ketidaknyaman... 2024-12-21 23:54:58
# 1  Halo Kak Tri Wahyu Widiyanto, maaf atas kendal... 2025-01-02 05:49:42
# 2  Hai Kak Nur Hendro, maaf untuk kendalanya. Sar... 2024-12-26 06:31:54
# 3                                               None                 NaT
# 4  Hai Kak Boy Jendri Hulu, mohon maaf atas ketid... 2024-12-21 01:47:07
#
#   appVersion
# 0      1.2.0
# 1      1.2.0
# 2      1.2.0
# 3      1.2.0
# 4      1.2.0

# %%
with open('hasil_scraping_wondrBNI.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    writer.writerow(['content','score'])


    for review in scrapreview_limited:
        writer.writerow([
            review['content'],
            review.get('score', '')
        ])

print("Data telah disimpan ke hasil_scraping_wondrBNI.csv")
# Out:
# Data telah disimpan ke hasil_screeping_wondrBNI.csv
